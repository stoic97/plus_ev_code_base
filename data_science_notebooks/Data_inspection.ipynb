# %%
### Importing the important libraries
import pandas as pd
from datetime import datetime
import os
import datetime
import numpy as np
from datetime import datetime, timedelta
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("nifty50_ohlc.csv")
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# Remove duplicated timestamps
if df.index.duplicated().any():
    print("There are duplicated timestamps.")
    df = df[~df.index.duplicated(keep='first')]

# Resample the data to 5-minute intervals
df_5min1 = df.resample('5min').agg({
    'open': 'first',
    'high': 'max',
    'low': 'min',
    'close': 'last'
})
df_5min1.dropna(how='all', inplace=True)
df_5min1.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7088b5762f61> in <cell line: 1>()
# ----> 1 df = pd.read_csv("nifty50_ohlc.csv")
#       2 df['date'] = pd.to_datetime(df['date'])
#       3 df.set_index('date', inplace=True)
#       4
#       5 # Remove duplicated timestamps
#
# ...

# %%
df_5min = pd.read_csv("nifty50_rik_5min.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-bd8d025f8ac6> in <cell line: 1>()
# ----> 1 df_5min = pd.read_csv("nifty50_rik_5min.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Plot the 'close' price against 'date'
plt.figure(figsize=(12, 6))
plt.plot(df_5min.index, df_5min['close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the 'close' price against 'date'
plt.figure(figsize=(12, 6))
plt.plot(df_5min1.index, df_5min1['close'], label='Close Price')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close Price Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_5min.shape
# Out:
# (178118, 6)

# %%
df_5min1.shape
# Out:
# (167366, 5)

# %%
df_5min["date"][0]
# Out:
# '2015-01-09 09:15:00+05:30'

# %%
df_5min1.head()
# Out:
#                  date     open     high      low    close
# 0 2015-01-09 09:15:00  8285.45  8301.30  8285.45  8301.20
# 1 2015-01-09 09:20:00  8300.50  8303.00  8293.25  8301.00
# 2 2015-01-09 09:25:00  8301.65  8302.55  8286.80  8294.15
# 3 2015-01-09 09:30:00  8294.10  8295.75  8280.65  8288.50
# 4 2015-01-09 09:35:00  8289.10  8290.45  8278.00  8283.45
